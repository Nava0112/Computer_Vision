# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
image = cv2.imread('wallpaperflare.com_wallpaper (7).jpg')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.show()

# %%
image = cv2.imread('wallpaperflare.com_wallpaper (7).jpg')

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(image_gray, cmap='grey')
plt.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

image = plt.imread('wallpaperflare.com_wallpaper (7).jpg')

if image.max() > 1:
    image = image / 255.0

grayscale = 0.2989 * image[..., 0] + 0.5870 * image[..., 1] + 0.1140 * image[..., 2]

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(grayscale, cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
image = cv2.imread('wallpaperflare.com_wallpaper (7).jpg')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
resized_image = cv2.resize(image_gray, (1000, 1000))

plt.imshow(resized_image, cmap='grey')
plt.axis('off')
plt.show()

# %%
image = cv2.imread('wallpaperflare.com_wallpaper (7).jpg')

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

equalized_image = cv2.equalizeHist(image_gray)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_gray, cmap='gray')
plt.title("Original Grayscale")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(equalized_image, cmap='gray')
plt.title("Equalized Image")
plt.axis('off')

plt.show()

# %%
image = cv2.imread(r"wallpaperflare.com_wallpaper (7).jpg", cv2.IMREAD_GRAYSCALE)

hist, bins = np.histogram(image.flatten(), 256, [0, 256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max() / cdf.max()

cdf_min = cdf[cdf > 0].min()
cdf = (cdf - cdf_min) * 255 / (cdf.max() - cdf_min)
cdf = cdf.astype('uint8')

equalized_image = cdf[image]

plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(image, cmap='gray')
plt.title("Original Image")
plt.axis("off")

plt.subplot(2, 2, 2)
plt.plot(hist, color='black')
plt.title("Histogram (Original Image)")

plt.subplot(2, 2, 3)
plt.imshow(equalized_image, cmap='gray')
plt.title("Equalized Image")
plt.axis("off")

plt.subplot(2, 2, 4)
equalized_hist, _ = np.histogram(equalized_image.flatten(), 256, [0, 256])
plt.plot(equalized_hist, color='black')
plt.title("Histogram (Equalized Image)")

plt.tight_layout()
plt.show()
